# %% [markdown]
# # pepbenchmark.dataset_manager Overview
#
# This notebook summarizes official dataset loading for both single-peptide and PPI benchmarks.

# %% [markdown]
# ## Typical Use Cases
#
# - Inspect the public API for the module.
# - Run a small, reproducible example.
# - Reuse the same pattern in scripts or larger benchmark workflows.

# %%
from pepbenchmark.dataset_manager.single_dataset import SinglePeptideDatasetManager
from pepbenchmark.dataset_manager.ppi_dataset import PPIDatasetManager

# %% [markdown]
# ## Example
#
# The following cell is intentionally lightweight so it can serve as a copy-paste starting point.

# %%
single = SinglePeptideDatasetManager("ace_inhibitory", official_feature_names=["fasta", "label"], dataset_dir="../../PepBenchData/PepBenchData-50")
ppi = PPIDatasetManager("PpI_ba", official_feature_names=["pep_fasta", "prot_fasta", "label"], dataset_dir="../../PepBenchData/PepBenchData-50")
(single.get_all_feature_names(), sorted(ppi.features.keys()))
# Out:
# 2026-03-27 05:19:55 | INFO     | pepbenchmark | Loaded official feature: fasta
# 2026-03-27 05:19:55 | INFO     | pepbenchmark | Loaded official feature: label
# 2026-03-27 05:19:55 | INFO     | pepbenchmark | Loaded official feature: pep_fasta
# 2026-03-27 05:19:55 | INFO     | pepbenchmark | Loaded official feature: prot_fasta
# 2026-03-27 05:19:55 | INFO     | pepbenchmark | Loaded official feature: label
# (['fasta', 'label'], ['label', 'pep_fasta', 'prot_fasta'])

# %% [markdown]
# ## Notes
#
# - Replace the toy inputs with official datasets when moving to full experiments.
# - The companion Sphinx page in `docs/source/package_intro` provides the static module summary.
