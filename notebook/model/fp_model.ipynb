# %% [markdown]
# # 1. canonical peptide classification

# %%
from pepbenchmark.model.fp_model import build_fp_model
from pepbenchmark.dataset_manager.single_dataset import SinglePeptideDatasetManager

dataset = SinglePeptideDatasetManager(
    "ace_inhibitory",
    official_feature_names=["ecfp6", "label"],
    dataset_dir="../../PepBenchData/PepBenchData-50",
)
runner = build_fp_model(
    "rf",
    model_name="rf_test",
    dataset=dataset,
    task_type="binary_classification",
    fingerprint_type="ecfp6",
)

multi_results = runner.run_multi(
    run_seeds=[42, 43, 44, 45, 46],
    fold_seeds=[0, 1, 2, 3, 4],
    split_type="hybrid_split",   
    base_dir="./results",
)
print(multi_results.to_dataframe())
summary = multi_results.get_summary_stats()
print(summary["test_roc-auc"])
# Out:
# 2026-03-28 11:03:51 | INFO     | pepbenchmark | Loaded official feature: ecfp6
# 2026-03-28 11:03:51 | INFO     | pepbenchmark | Loaded official feature: label
# 2026-03-28 11:03:51 | INFO     | pepbenchmark | [RUN_MULTI] running seed=42, fold=0
# 2026-03-28 11:03:51 | INFO     | pepbenchmark | [RUN] rf_test | seed=42, fold=0, split=hybrid_split
# 2026-03-28 11:03:51 | INFO     | pepbenchmark | Set official split ===hybrid_split=== with seed ====0=== successfully
# 2026-03-28 11:03:51 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 11:03:52 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 0.65s
# 2026-03-28 11:03:52 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/ace_inhibitory/rf_test/hybrid_split/fold_0/run_42/model.joblib
# 2026-03-28 11:03:52 | INFO     | pepbenchmark | [METRICS] train: {'accuracy': 1.0, 'balanced-accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'specificity': np.float64(1.0), 'f1': 1.0, 'micro-f1': 1.0, 'macro-f1': 1.0, 'weighted-f1': 1.0, 'mcc': 1.0, 'kappa': 1.0, 'g-mean': np.float64(1.0), 'roc-auc': 1.0, 'avg-roc-auc': 1.0, 'pr-auc': 0.9999999999999999, 'brier-score': 0.02150986214209968, 'log-loss': 0.13389148300140422}
# 2026-03-28 11:03:52 | INFO     | pepbenchmark | [METRICS] valid: {'accuracy': 0.7280453257790368, 'balanced-accuracy': 0.720229839508619, 'precision': 0.673469387755102, 'recall': 0.673469387755102, 'specificity': np.float64(0.7669902912621359), 'f1': 0.673469387755102, 'micro-f1': 0.7280453257790368, 'macro-f1': 0.720229839508619, 'weighted-f1': 0.7280453257790368, 'mcc': 0.440459679017238, 'kappa': 0.4404596790172379, 'g-mean': np.float64(0.7187102906390154), 'roc-auc': 0.7932765339145367, 'avg-roc-auc': 0.7932765339145367, 'pr-auc': 0.7491672338189541, 'brier-score': 0.18192946175637395, 'log-loss': 0.5388863944575795}
# 2026-03-28 11:03:52 | INFO     | pepbenchmark | [METRICS] test: {'accuracy': 0.7690140845070422, 'balanced-accuracy': 0.7670709793351302, 'precision': 0.7391304347826086, 'recall': 0.7484276729559748, 'specificity': np.float64(0.7857142857142857), 'f1': 0.74375, 'micro-f1': 0.7690140845070422, 'macro-f1': 0.7667467948717949, 'weighted-f1': 0.7691436439147707, 'mcc': 0.533543077487806, 'kappa': 0.533508541392904, 'g-mean': np.float64(0.7668443873859995), 'roc-auc': 0.816888075985111, 'avg-roc-auc': 0.816888075985111, 'pr-auc': 0.7857566974936299, 'brier-score': 0.17407661971830987, 'log-loss': 0.527107081469855}
# 2026-03-28 11:03:52 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/ace_inhibitory/rf_test/hybrid_split/fold_0/run_42
# 2026-03-28 11:03:52 | INFO     | pepbenchmark | [RUN_MULTI] running seed=43, fold=1
# 2026-03-28 11:03:52 | INFO     | pepbenchmark | [RUN] rf_test | seed=43, fold=1, split=hybrid_split
# 2026-03-28 11:03:52 | INFO     | pepbenchmark | Set official split ===hybrid_split=== with seed ====1=== successfully
# 2026-03-28 11:03:52 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 11:03:53 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 0.61s
# 2026-03-28 11:03:53 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/ace_inhibitory/rf_test/hybrid_split/fold_1/run_43/model.joblib
# 2026-03-28 11:03:53 | INFO     | pepbenchmark | [METRICS] train: {'accuracy': 1.0, 'balanced-accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'specificity': np.float64(1.0), 'f1': 1.0, 'micro-f1': 1.0, 'macro-f1': 1.0, 'weighted-f1': 1.0, 'mcc': 1.0, 'kappa': 1.0, 'g-mean': np.float64(1.0), 'roc-auc': 1.0, 'avg-roc-auc': 1.0, 'pr-auc': 1.0, 'brier-score': 0.02236645457758925, 'log-loss': 0.13641421607337575}
# 2026-03-28 11:03:53 | INFO     | pepbenchmark | [METRICS] valid: {'accuracy': 0.7478753541076487, 'balanced-accuracy': 0.7412464756409416, 'precision': 0.7094594594594594, 'recall': 0.695364238410596, 'specificity': np.float64(0.7871287128712872), 'f1': 0.7023411371237458, 'micro-f1': 0.7478753541076487, 'macro-f1': 0.7418339592252636, 'weighted-f1': 0.7475397210586274, 'mcc': 0.4837793685039646, 'kappa': 0.48370610178961726, 'g-mean': np.float64(0.7398250860553833), 'roc-auc': 0.8062094288899089, 'avg-roc-auc': 0.8062094288899089, 'pr-auc': 0.7561853151023062, 'brier-score': 0.1790940509915014, 'log-loss': 0.538099079121328}
# 2026-03-28 11:03:53 | INFO     | pepbenchmark | [METRICS] test: {'accuracy': 0.7352112676056338, 'balanced-accuracy': 0.7341016472991955, 'precision': 0.7108433734939759, 'recall': 0.7195121951219512, 'specificity': np.float64(0.7486910994764397), 'f1': 0.7151515151515152, 'micro-f1': 0.7352112676056338, 'macro-f1': 0.7338915470494418, 'weighted-f1': 0.7353168452501291, 'mcc': 0.46783006359141677, 'kappa': 0.46780007017320024, 'g-mean': np.float64(0.733956658429202), 'roc-auc': 0.8252937045077258, 'avg-roc-auc': 0.8252937045077258, 'pr-auc': 0.8067784460675824, 'brier-score': 0.17096169014084509, 'log-loss': 0.5130886991889708}
# 2026-03-28 11:03:53 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/ace_inhibitory/rf_test/hybrid_split/fold_1/run_43
# 2026-03-28 11:03:53 | INFO     | pepbenchmark | [RUN_MULTI] running seed=44, fold=2
# 2026-03-28 11:03:53 | INFO     | pepbenchmark | [RUN] rf_test | seed=44, fold=2, split=hybrid_split
# 2026-03-28 11:03:53 | INFO     | pepbenchmark | Set official split ===hybrid_split=== with seed ====2=== successfully
# 2026-03-28 11:03:53 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 11:03:54 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 0.62s
# 2026-03-28 11:03:54 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/ace_inhibitory/rf_test/hybrid_split/fold_2/run_44/model.joblib
# 2026-03-28 11:03:54 | INFO     | pepbenchmark | [METRICS] train: {'accuracy': 1.0, 'balanced-accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'specificity': np.float64(1.0), 'f1': 1.0, 'micro-f1': 1.0, 'macro-f1': 1.0, 'weighted-f1': 1.0, 'mcc': 1.0, 'kappa': 1.0, 'g-mean': np.float64(1.0), 'roc-auc': 0.9999999999999999, 'avg-roc-auc': 0.9999999999999999, 'pr-auc': 1.0000000000000002, 'brier-score': 0.022070731707317073, 'log-loss': 0.1355015006827367}
# 2026-03-28 11:03:54 | INFO     | pepbenchmark | [METRICS] valid: {'accuracy': 0.7138810198300283, 'balanced-accuracy': 0.7130436185314234, 'precision': 0.688622754491018, 'recall': 0.7012195121951219, 'specificity': np.float64(0.7248677248677249), 'f1': 0.6948640483383686, 'micro-f1': 0.7138810198300283, 'macro-f1': 0.7127653575025177, 'weighted-f1': 0.7140331556019616, 'mcc': 0.42563432495652065, 'kappa': 0.42557236534712484, 'g-mean': np.float64(0.7129455746673331), 'roc-auc': 0.7995225190347143, 'avg-roc-auc': 0.7995225190347143, 'pr-auc': 0.7595112659036254, 'brier-score': 0.18362606232294615, 'log-loss': 0.5504945173244243}
# 2026-03-28 11:03:54 | INFO     | pepbenchmark | [METRICS] test: {'accuracy': 0.7183098591549296, 'balanced-accuracy': 0.7144230769230769, 'precision': 0.6923076923076923, 'recall': 0.675, 'specificity': np.float64(0.7538461538461538), 'f1': 0.6835443037974683, 'micro-f1': 0.7183098591549296, 'macro-f1': 0.7148685985992418, 'weighted-f1': 0.7179569093543462, 'mcc': 0.42992230648888485, 'kappa': 0.42981047221329904, 'g-mean': np.float64(0.7133345315110953), 'roc-auc': 0.8131410256410257, 'avg-roc-auc': 0.8131410256410257, 'pr-auc': 0.7973256642935092, 'brier-score': 0.17448873239436619, 'log-loss': 0.5191585920710038}
# 2026-03-28 11:03:54 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/ace_inhibitory/rf_test/hybrid_split/fold_2/run_44
# 2026-03-28 11:03:54 | INFO     | pepbenchmark | [RUN_MULTI] running seed=45, fold=3
# 2026-03-28 11:03:54 | INFO     | pepbenchmark | [RUN] rf_test | seed=45, fold=3, split=hybrid_split
# 2026-03-28 11:03:54 | INFO     | pepbenchmark | Set official split ===hybrid_split=== with seed ====3=== successfully
# 2026-03-28 11:03:54 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 11:03:55 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 0.63s
# 2026-03-28 11:03:55 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/ace_inhibitory/rf_test/hybrid_split/fold_3/run_45/model.joblib
# 2026-03-28 11:03:55 | INFO     | pepbenchmark | [METRICS] train: {'accuracy': 1.0, 'balanced-accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'specificity': np.float64(1.0), 'f1': 1.0, 'micro-f1': 1.0, 'macro-f1': 1.0, 'weighted-f1': 1.0, 'mcc': 1.0, 'kappa': 1.0, 'g-mean': np.float64(1.0), 'roc-auc': 1.0, 'avg-roc-auc': 1.0, 'pr-auc': 1.0, 'brier-score': 0.022227925061859315, 'log-loss': 0.13682255303290258}
# 2026-03-28 11:03:55 | INFO     | pepbenchmark | [METRICS] valid: {'accuracy': 0.7393767705382436, 'balanced-accuracy': 0.7377319859982828, 'precision': 0.6729559748427673, 'recall': 0.7278911564625851, 'specificity': np.float64(0.7475728155339806), 'f1': 0.6993464052287581, 'micro-f1': 0.7393767705382436, 'macro-f1': 0.7346732026143791, 'weighted-f1': 0.7405776814975282, 'mcc': 0.4710971366061115, 'kappa': 0.46996996996997, 'g-mean': np.float64(0.737666348181222), 'roc-auc': 0.8089459084604717, 'avg-roc-auc': 0.8089459084604717, 'pr-auc': 0.7719460153622015, 'brier-score': 0.17844135977337108, 'log-loss': 0.5315273125347186}
# 2026-03-28 11:03:55 | INFO     | pepbenchmark | [METRICS] test: {'accuracy': 0.7690140845070422, 'balanced-accuracy': 0.7661133760434867, 'precision': 0.7261146496815286, 'recall': 0.7450980392156863, 'specificity': np.float64(0.7871287128712872), 'f1': 0.7354838709677419, 'micro-f1': 0.7690140845070422, 'macro-f1': 0.765241935483871, 'weighted-f1': 0.7693493866424352, 'mcc': 0.530683615316163, 'kappa': 0.5305444458779511, 'g-mean': np.float64(0.765825084840372), 'roc-auc': 0.839092732802692, 'avg-roc-auc': 0.839092732802692, 'pr-auc': 0.795263609302505, 'brier-score': 0.16522084507042253, 'log-loss': 0.49997753981284504}
# 2026-03-28 11:03:55 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/ace_inhibitory/rf_test/hybrid_split/fold_3/run_45
# 2026-03-28 11:03:55 | INFO     | pepbenchmark | [RUN_MULTI] running seed=46, fold=4
# 2026-03-28 11:03:55 | INFO     | pepbenchmark | [RUN] rf_test | seed=46, fold=4, split=hybrid_split
# 2026-03-28 11:03:55 | INFO     | pepbenchmark | Set official split ===hybrid_split=== with seed ====4=== successfully
# 2026-03-28 11:03:55 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 11:03:56 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 0.62s
# 2026-03-28 11:03:56 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/ace_inhibitory/rf_test/hybrid_split/fold_4/run_46/model.joblib
# 2026-03-28 11:03:57 | INFO     | pepbenchmark | [METRICS] train: {'accuracy': 1.0, 'balanced-accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'specificity': np.float64(1.0), 'f1': 1.0, 'micro-f1': 1.0, 'macro-f1': 1.0, 'weighted-f1': 1.0, 'mcc': 1.0, 'kappa': 1.0, 'g-mean': np.float64(1.0), 'roc-auc': 1.0, 'avg-roc-auc': 1.0, 'pr-auc': 1.0, 'brier-score': 0.022184658890067162, 'log-loss': 0.13550309733455845}
# 2026-03-28 11:03:57 | INFO     | pepbenchmark | [METRICS] valid: {'accuracy': 0.7365439093484419, 'balanced-accuracy': 0.7279130152547875, 'precision': 0.7338129496402878, 'recall': 0.6455696202531646, 'specificity': np.float64(0.8102564102564103), 'f1': 0.6868686868686869, 'micro-f1': 0.7365439093484419, 'macro-f1': 0.7297424118940011, 'weighted-f1': 0.7342362584263995, 'mcc': 0.4639067426690229, 'kappa': 0.4610863962440698, 'g-mean': np.float64(0.723240570679579), 'roc-auc': 0.7925998052580331, 'avg-roc-auc': 0.7925998052580331, 'pr-auc': 0.7834995053795651, 'brier-score': 0.1820011331444759, 'log-loss': 0.5464979180492905}
# 2026-03-28 11:03:57 | INFO     | pepbenchmark | [METRICS] test: {'accuracy': 0.7633802816901408, 'balanced-accuracy': 0.7575435887537798, 'precision': 0.7449664429530202, 'recall': 0.7070063694267515, 'specificity': np.float64(0.8080808080808081), 'f1': 0.7254901960784313, 'micro-f1': 0.7633802816901408, 'macro-f1': 0.7587847019996117, 'weighted-f1': 0.7626299829651564, 'mcc': 0.5183658897115445, 'kappa': 0.5178190285233815, 'g-mean': np.float64(0.7558559904668665), 'roc-auc': 0.8204497201312487, 'avg-roc-auc': 0.8204497201312487, 'pr-auc': 0.7772906167743465, 'brier-score': 0.1726554929577465, 'log-loss': 0.522074657815692}
# 2026-03-28 11:03:57 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/ace_inhibitory/rf_test/hybrid_split/fold_4/run_46
# 2026-03-28 11:03:57 | INFO     | pepbenchmark | [RUN_MULTI DONE] total runs: 5
#    random_seed  fold_seed model_name  train_samples  valid_samples  \
# 0           42          0    rf_test           2829            353
# 1           43          1    rf_test           2829            353
# 2           44          2    rf_test           2829            353
# 3           45          3    rf_test           2829            353
# 4           46          4    rf_test           2829            353
#
#    test_samples  training_time  train_accuracy  train_balanced-accuracy  \
# 0           355       0.646913             1.0                      1.0
# 1           355       0.610564             1.0                      1.0
# 2           355       0.621634             1.0                      1.0
# 3           355       0.632294             1.0                      1.0
# 4           355       0.623658             1.0                      1.0
#
#    train_precision  ...  test_macro-f1  test_weighted-f1  test_mcc  \
# 0              1.0  ...       0.766747          0.769144  0.533543
# 1              1.0  ...       0.733892          0.735317  0.467830
# 2              1.0  ...       0.714869          0.717957  0.429922
# 3              1.0  ...       0.765242          0.769349  0.530684
# 4              1.0  ...       0.758785          0.762630  0.518366
#
#    test_kappa  test_g-mean  test_roc-auc  test_avg-roc-auc  test_pr-auc  \
# 0    0.533509     0.766844      0.816888          0.816888     0.785757
# 1    0.467800     0.733957      0.825294          0.825294     0.806778
# 2    0.429810     0.713335      0.813141          0.813141     0.797326
# 3    0.530544     0.765825      0.839093          0.839093     0.795264
# 4    0.517819     0.755856      0.820450          0.820450     0.777291
#
#    test_brier-score  test_log-loss
# 0          0.174077       0.527107
# 1          0.170962       0.513089
# 2          0.174489       0.519159
# 3          0.165221       0.499978
# 4          0.172655       0.522075
#
# [5 rows x 58 columns]
# {'mean': 0.8229730518135607, 'std': 0.01006593781507076, 'min': 0.8131410256410257, 'max': 0.839092732802692}

# %% [markdown]
# # 2. canonical peptide regression

# %%
from pepbenchmark.model.fp_model import build_fp_model
from pepbenchmark.dataset_manager.single_dataset import SinglePeptideDatasetManager

dataset = SinglePeptideDatasetManager(
    "antimicrobial_P_aeruginosa_mic",
    official_feature_names=["ecfp6", "label"],
    dataset_dir="../../PepBenchData/PepBenchData-50",
)
runner = build_fp_model(
    "rf",
    model_name="rf_test",
    dataset=dataset,
    task_type="regression",
    fingerprint_type="ecfp6",
)

multi_results = runner.run_multi(
    run_seeds=[42, 43, 44, 45, 46],
    fold_seeds=[0, 1, 2, 3, 4],
    split_type="hybrid_split",   
    base_dir="./results",
)
print(multi_results.to_dataframe())
summary = multi_results.get_summary_stats()
print(summary["test_mae"])
# Out:
# 2026-03-28 11:08:34 | INFO     | pepbenchmark | Loaded official feature: ecfp6
# 2026-03-28 11:08:34 | INFO     | pepbenchmark | Loaded official feature: label
# 2026-03-28 11:08:34 | INFO     | pepbenchmark | [RUN_MULTI] running seed=42, fold=0
# 2026-03-28 11:08:34 | INFO     | pepbenchmark | [RUN] rf_test | seed=42, fold=0, split=hybrid_split
# 2026-03-28 11:08:34 | INFO     | pepbenchmark | Set official split ===hybrid_split=== with seed ====0=== successfully
# 2026-03-28 11:08:34 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 11:08:39 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 4.79s
# 2026-03-28 11:08:39 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/antimicrobial_P_aeruginosa_mic/rf_test/hybrid_split/fold_0/run_42/model.joblib
# 2026-03-28 11:08:39 | INFO     | pepbenchmark | [METRICS] train: {'mse': 0.04357120033650885, 'rmse': np.float64(0.20873715609950436), 'mae': 0.15643967882158288, 'r2': 0.9049434466915565, 'pcc': np.float64(0.9674580101407102), 'spearman': np.float64(0.9667420036515038)}
# 2026-03-28 11:08:39 | INFO     | pepbenchmark | [METRICS] valid: {'mse': 0.536042500015043, 'rmse': np.float64(0.7321492334319849), 'mae': 0.5856093071885199, 'r2': 0.10561583825745668, 'pcc': np.float64(0.368756287621415), 'spearman': np.float64(0.31036853534881204)}
# 2026-03-28 11:08:39 | INFO     | pepbenchmark | [METRICS] test: {'mse': 0.37647600895804234, 'rmse': np.float64(0.6135764084105926), 'mae': 0.49256309062881865, 'r2': 0.11091856485920149, 'pcc': np.float64(0.4759503795429696), 'spearman': np.float64(0.4368881509140015)}
# 2026-03-28 11:08:39 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/antimicrobial_P_aeruginosa_mic/rf_test/hybrid_split/fold_0/run_42
# 2026-03-28 11:08:39 | INFO     | pepbenchmark | [RUN_MULTI] running seed=43, fold=1
# 2026-03-28 11:08:39 | INFO     | pepbenchmark | [RUN] rf_test | seed=43, fold=1, split=hybrid_split
# 2026-03-28 11:08:39 | INFO     | pepbenchmark | Set official split ===hybrid_split=== with seed ====1=== successfully
# 2026-03-28 11:08:39 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 11:08:44 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 5.31s
# 2026-03-28 11:08:44 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/antimicrobial_P_aeruginosa_mic/rf_test/hybrid_split/fold_1/run_43/model.joblib
# 2026-03-28 11:08:44 | INFO     | pepbenchmark | [METRICS] train: {'mse': 0.04125007625583097, 'rmse': np.float64(0.20310114784469085), 'mae': 0.15293174494784473, 'r2': 0.9096355610296099, 'pcc': np.float64(0.9695283270141537), 'spearman': np.float64(0.9707240555155967)}
# 2026-03-28 11:08:45 | INFO     | pepbenchmark | [METRICS] valid: {'mse': 0.461258394823616, 'rmse': np.float64(0.6791600656867393), 'mae': 0.5325828906326274, 'r2': 0.22288355332663767, 'pcc': np.float64(0.4726038019984188), 'spearman': np.float64(0.415835146874581)}
# 2026-03-28 11:08:45 | INFO     | pepbenchmark | [METRICS] test: {'mse': 0.5118306976242154, 'rmse': np.float64(0.7154234393869238), 'mae': 0.549276425197705, 'r2': -0.04636480952976196, 'pcc': np.float64(0.26594230109382994), 'spearman': np.float64(0.2016808555333714)}
# 2026-03-28 11:08:45 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/antimicrobial_P_aeruginosa_mic/rf_test/hybrid_split/fold_1/run_43
# 2026-03-28 11:08:45 | INFO     | pepbenchmark | [RUN_MULTI] running seed=44, fold=2
# 2026-03-28 11:08:45 | INFO     | pepbenchmark | [RUN] rf_test | seed=44, fold=2, split=hybrid_split
# 2026-03-28 11:08:45 | INFO     | pepbenchmark | Set official split ===hybrid_split=== with seed ====2=== successfully
# 2026-03-28 11:08:45 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 11:08:50 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 5.28s
# 2026-03-28 11:08:50 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/antimicrobial_P_aeruginosa_mic/rf_test/hybrid_split/fold_2/run_44/model.joblib
# 2026-03-28 11:08:50 | INFO     | pepbenchmark | [METRICS] train: {'mse': 0.04329519409502887, 'rmse': np.float64(0.20807497229371164), 'mae': 0.15390478733538054, 'r2': 0.9038080368791898, 'pcc': np.float64(0.9674853557678528), 'spearman': np.float64(0.9701665639942586)}
# 2026-03-28 11:08:50 | INFO     | pepbenchmark | [METRICS] valid: {'mse': 0.48140391150774037, 'rmse': np.float64(0.6938327691221714), 'mae': 0.5418613679235318, 'r2': 0.16673232561109808, 'pcc': np.float64(0.4527053154205277), 'spearman': np.float64(0.4430327761269527)}
# 2026-03-28 11:08:50 | INFO     | pepbenchmark | [METRICS] test: {'mse': 0.5246224222814675, 'rmse': np.float64(0.7243082370658693), 'mae': 0.5611023242570371, 'r2': 0.031842722159830084, 'pcc': np.float64(0.28099189248217116), 'spearman': np.float64(0.25767222851624494)}
# 2026-03-28 11:08:50 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/antimicrobial_P_aeruginosa_mic/rf_test/hybrid_split/fold_2/run_44
# 2026-03-28 11:08:50 | INFO     | pepbenchmark | [RUN_MULTI] running seed=45, fold=3
# 2026-03-28 11:08:50 | INFO     | pepbenchmark | [RUN] rf_test | seed=45, fold=3, split=hybrid_split
# 2026-03-28 11:08:50 | INFO     | pepbenchmark | Set official split ===hybrid_split=== with seed ====3=== successfully
# 2026-03-28 11:08:50 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 11:08:55 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 5.24s
# 2026-03-28 11:08:55 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/antimicrobial_P_aeruginosa_mic/rf_test/hybrid_split/fold_3/run_45/model.joblib
# 2026-03-28 11:08:55 | INFO     | pepbenchmark | [METRICS] train: {'mse': 0.04585526587463228, 'rmse': np.float64(0.2141384268986589), 'mae': 0.15838224040474888, 'r2': 0.9039365401689322, 'pcc': np.float64(0.9672763592685103), 'spearman': np.float64(0.9697014361118952)}
# 2026-03-28 11:08:55 | INFO     | pepbenchmark | [METRICS] valid: {'mse': 0.3802486353229891, 'rmse': np.float64(0.6166430371965527), 'mae': 0.49035367303988825, 'r2': 0.08919965236219096, 'pcc': np.float64(0.3657850041616927), 'spearman': np.float64(0.2845496754785403)}
# 2026-03-28 11:08:55 | INFO     | pepbenchmark | [METRICS] test: {'mse': 0.4682959117743014, 'rmse': np.float64(0.6843214973784627), 'mae': 0.5531847507432698, 'r2': 0.12141934690099665, 'pcc': np.float64(0.37356437812957954), 'spearman': np.float64(0.3437488394779262)}
# 2026-03-28 11:08:55 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/antimicrobial_P_aeruginosa_mic/rf_test/hybrid_split/fold_3/run_45
# 2026-03-28 11:08:55 | INFO     | pepbenchmark | [RUN_MULTI] running seed=46, fold=4
# 2026-03-28 11:08:55 | INFO     | pepbenchmark | [RUN] rf_test | seed=46, fold=4, split=hybrid_split
# 2026-03-28 11:08:55 | INFO     | pepbenchmark | Set official split ===hybrid_split=== with seed ====4=== successfully
# 2026-03-28 11:08:55 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 11:09:00 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 5.02s
# 2026-03-28 11:09:01 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/antimicrobial_P_aeruginosa_mic/rf_test/hybrid_split/fold_4/run_46/model.joblib
# 2026-03-28 11:09:01 | INFO     | pepbenchmark | [METRICS] train: {'mse': 0.042641266916653923, 'rmse': np.float64(0.20649761963919566), 'mae': 0.15554767485700005, 'r2': 0.9097634120232516, 'pcc': np.float64(0.9693486998418483), 'spearman': np.float64(0.9702648125177279)}
# 2026-03-28 11:09:01 | INFO     | pepbenchmark | [METRICS] valid: {'mse': 0.49348925343209654, 'rmse': np.float64(0.7024879026944852), 'mae': 0.5556038280200452, 'r2': -0.1683374712736465, 'pcc': np.float64(0.15599840593403616), 'spearman': np.float64(0.10928269994984821)}
# 2026-03-28 11:09:01 | INFO     | pepbenchmark | [METRICS] test: {'mse': 0.47980841191919116, 'rmse': np.float64(0.6926820424402463), 'mae': 0.5223019089259547, 'r2': 0.10839543411104502, 'pcc': np.float64(0.37082721541263886), 'spearman': np.float64(0.3532641673235786)}
# 2026-03-28 11:09:01 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/antimicrobial_P_aeruginosa_mic/rf_test/hybrid_split/fold_4/run_46
# 2026-03-28 11:09:01 | INFO     | pepbenchmark | [RUN_MULTI DONE] total runs: 5
#    random_seed  fold_seed model_name  train_samples  valid_samples  \
# 0           42          0    rf_test           1192            149
# 1           43          1    rf_test           1192            149
# 2           44          2    rf_test           1192            149
# 3           45          3    rf_test           1192            149
# 4           46          4    rf_test           1192            149
#
#    test_samples  training_time  train_mse  train_rmse  train_mae  ...  \
# 0           149       4.790846   0.043571    0.208737   0.156440  ...
# 1           149       5.314049   0.041250    0.203101   0.152932  ...
# 2           149       5.278954   0.043295    0.208075   0.153905  ...
# 3           149       5.239675   0.045855    0.214138   0.158382  ...
# 4           149       5.021316   0.042641    0.206498   0.155548  ...
#
#    valid_mae  valid_r2  valid_pcc  valid_spearman  test_mse  test_rmse  \
# 0   0.585609  0.105616   0.368756        0.310369  0.376476   0.613576
# 1   0.532583  0.222884   0.472604        0.415835  0.511831   0.715423
# 2   0.541861  0.166732   0.452705        0.443033  0.524622   0.724308
# 3   0.490354  0.089200   0.365785        0.284550  0.468296   0.684321
# 4   0.555604 -0.168337   0.155998        0.109283  0.479808   0.692682
#
#    test_mae   test_r2  test_pcc  test_spearman
# 0  0.492563  0.110919  0.475950       0.436888
# 1  0.549276 -0.046365  0.265942       0.201681
# 2  0.561102  0.031843  0.280992       0.257672
# 3  0.553185  0.121419  0.373564       0.343749
# 4  0.522302  0.108395  0.370827       0.353264
#
# [5 rows x 25 columns]
# {'mean': 0.535685699950557, 'std': 0.028176296240952532, 'min': 0.49256309062881865, 'max': 0.5611023242570371}

# %% [markdown]
# # 4. non-canonical peptide classification

# %%
from pepbenchmark.model.fp_model import build_fp_model
from pepbenchmark.dataset_manager.single_dataset import SinglePeptideDatasetManager

dataset = SinglePeptideDatasetManager(
    "nc-antifungal",
    official_feature_names=["ecfp6", "label"],
    dataset_dir="../../PepBenchData/PepBenchData-50",
)
runner = build_fp_model(
    "rf",
    model_name="rf_test",
    dataset=dataset,
    task_type="binary_classification",
    fingerprint_type="ecfp6",
)

multi_results = runner.run_multi(
    run_seeds=[42, 43, 44, 45, 46],
    fold_seeds=[0, 1, 2, 3, 4],
    split_type="ecfp_split",   
    base_dir="./results",
)
print(multi_results.to_dataframe())
summary = multi_results.get_summary_stats()
print(summary["test_roc-auc"])
# Out:
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | Loaded official feature: ecfp6
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | Loaded official feature: label
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [RUN_MULTI] running seed=42, fold=0
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [RUN] rf_test | seed=42, fold=0, split=ecfp_split
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | Set official split ===ecfp_split=== with seed ====0=== successfully
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 0.12s
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/nc-antifungal/rf_test/ecfp_split/fold_0/run_42/model.joblib
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [METRICS] train: {'accuracy': 1.0, 'balanced-accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'specificity': np.float64(1.0), 'f1': 1.0, 'micro-f1': 1.0, 'macro-f1': 1.0, 'weighted-f1': 1.0, 'mcc': 1.0, 'kappa': 1.0, 'g-mean': np.float64(1.0), 'roc-auc': 0.9999999999999999, 'avg-roc-auc': 0.9999999999999999, 'pr-auc': 1.0, 'brier-score': 0.007925776397515528, 'log-loss': 0.06259736538824813}
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [METRICS] valid: {'accuracy': 0.825, 'balanced-accuracy': 0.7833333333333333, 'precision': 0.6363636363636364, 'recall': 0.7, 'specificity': np.float64(0.8666666666666667), 'f1': 0.6666666666666666, 'micro-f1': 0.825, 'macro-f1': 0.7740112994350282, 'weighted-f1': 0.827683615819209, 'mcc': 0.5495319562599505, 'kappa': 0.5483870967741935, 'g-mean': np.float64(0.7788880963698616), 'roc-auc': 0.9016666666666666, 'avg-roc-auc': 0.9016666666666666, 'pr-auc': 0.7503263403263403, 'brier-score': 0.11480750000000002, 'log-loss': 0.3719957260897452}
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [METRICS] test: {'accuracy': 0.8048780487804879, 'balanced-accuracy': 0.8370967741935484, 'precision': 0.5625, 'recall': 0.9, 'specificity': np.float64(0.7741935483870968), 'f1': 0.6923076923076923, 'micro-f1': 0.8048780487804879, 'macro-f1': 0.7747252747252746, 'weighted-f1': 0.8169391584025729, 'mcc': 0.5935201167881827, 'kappa': 0.5603217158176943, 'g-mean': np.float64(0.8347300123683029), 'roc-auc': 0.9451612903225807, 'avg-roc-auc': 0.9451612903225807, 'pr-auc': 0.8521568627450979, 'brier-score': 0.11419756097560978, 'log-loss': 0.37146181357914}
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/nc-antifungal/rf_test/ecfp_split/fold_0/run_42
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [RUN_MULTI] running seed=43, fold=1
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [RUN] rf_test | seed=43, fold=1, split=ecfp_split
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | Set official split ===ecfp_split=== with seed ====1=== successfully
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 0.12s
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/nc-antifungal/rf_test/ecfp_split/fold_1/run_43/model.joblib
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [METRICS] train: {'accuracy': 1.0, 'balanced-accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'specificity': np.float64(1.0), 'f1': 1.0, 'micro-f1': 1.0, 'macro-f1': 1.0, 'weighted-f1': 1.0, 'mcc': 1.0, 'kappa': 1.0, 'g-mean': np.float64(1.0), 'roc-auc': 1.0, 'avg-roc-auc': 1.0, 'pr-auc': 1.0, 'brier-score': 0.007440372670807453, 'log-loss': 0.059955881192495036}
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [METRICS] valid: {'accuracy': 0.825, 'balanced-accuracy': 0.7946708463949843, 'precision': 0.6666666666666666, 'recall': 0.7272727272727273, 'specificity': np.float64(0.8620689655172413), 'f1': 0.6956521739130435, 'micro-f1': 0.825, 'macro-f1': 0.7864225781845919, 'weighted-f1': 0.8272692601067886, 'mcc': 0.5742392437486782, 'kappa': 0.573170731707317, 'g-mean': np.float64(0.7918075824648958), 'roc-auc': 0.9341692789968651, 'avg-roc-auc': 0.9341692789968651, 'pr-auc': 0.8727272727272727, 'brier-score': 0.10188250000000001, 'log-loss': 0.332031930899974}
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [METRICS] test: {'accuracy': 0.7804878048780488, 'balanced-accuracy': 0.7689393939393939, 'precision': 0.46153846153846156, 'recall': 0.75, 'specificity': np.float64(0.7878787878787878), 'f1': 0.5714285714285714, 'micro-f1': 0.7804878048780488, 'macro-f1': 0.7119437939110069, 'weighted-f1': 0.7976238076198091, 'mcc': 0.4580740495071019, 'kappa': 0.43491577335375187, 'g-mean': np.float64(0.7687061147858073), 'roc-auc': 0.9204545454545454, 'avg-roc-auc': 0.9204545454545454, 'pr-auc': 0.8010912698412699, 'brier-score': 0.13555121951219515, 'log-loss': 0.42323779761512065}
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/nc-antifungal/rf_test/ecfp_split/fold_1/run_43
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [RUN_MULTI] running seed=44, fold=2
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [RUN] rf_test | seed=44, fold=2, split=ecfp_split
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | Set official split ===ecfp_split=== with seed ====2=== successfully
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 0.12s
# 2026-03-28 13:47:32 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/nc-antifungal/rf_test/ecfp_split/fold_2/run_44/model.joblib
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [METRICS] train: {'accuracy': 1.0, 'balanced-accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'specificity': np.float64(1.0), 'f1': 1.0, 'micro-f1': 1.0, 'macro-f1': 1.0, 'weighted-f1': 1.0, 'mcc': 1.0, 'kappa': 1.0, 'g-mean': np.float64(1.0), 'roc-auc': 1.0, 'avg-roc-auc': 1.0, 'pr-auc': 1.0, 'brier-score': 0.007613043478260871, 'log-loss': 0.06145932472187085}
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [METRICS] valid: {'accuracy': 0.9, 'balanced-accuracy': 0.8960573476702509, 'precision': 0.7272727272727273, 'recall': 0.8888888888888888, 'specificity': np.float64(0.9032258064516129), 'f1': 0.8, 'micro-f1': 0.9, 'macro-f1': 0.8666666666666667, 'weighted-f1': 0.9033333333333333, 'mcc': 0.740789521357966, 'kappa': 0.7342192691029901, 'g-mean': np.float64(0.8960286733763294), 'roc-auc': 0.953405017921147, 'avg-roc-auc': 0.953405017921147, 'pr-auc': 0.8586640211640212, 'brier-score': 0.086535, 'log-loss': 0.30080505545287367}
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [METRICS] test: {'accuracy': 0.8292682926829268, 'balanced-accuracy': 0.8131868131868132, 'precision': 0.7142857142857143, 'recall': 0.7692307692307693, 'specificity': np.float64(0.8571428571428571), 'f1': 0.7407407407407407, 'micro-f1': 0.8292682926829268, 'macro-f1': 0.8067340067340067, 'weighted-f1': 0.8308778845364211, 'mcc': 0.6146646756784948, 'kappa': 0.6137281292059219, 'g-mean': np.float64(0.8119979429411501), 'roc-auc': 0.9478021978021978, 'avg-roc-auc': 0.9478021978021978, 'pr-auc': 0.8915158371040723, 'brier-score': 0.11036341463414634, 'log-loss': 0.36611860273681185}
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/nc-antifungal/rf_test/ecfp_split/fold_2/run_44
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [RUN_MULTI] running seed=45, fold=3
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [RUN] rf_test | seed=45, fold=3, split=ecfp_split
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | Set official split ===ecfp_split=== with seed ====3=== successfully
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 0.12s
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/nc-antifungal/rf_test/ecfp_split/fold_3/run_45/model.joblib
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [METRICS] train: {'accuracy': 1.0, 'balanced-accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'specificity': np.float64(1.0), 'f1': 1.0, 'micro-f1': 1.0, 'macro-f1': 1.0, 'weighted-f1': 1.0, 'mcc': 1.0, 'kappa': 1.0, 'g-mean': np.float64(1.0), 'roc-auc': 1.0, 'avg-roc-auc': 1.0, 'pr-auc': 1.0, 'brier-score': 0.008162422360248448, 'log-loss': 0.06312158741956364}
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [METRICS] valid: {'accuracy': 0.875, 'balanced-accuracy': 0.8466666666666667, 'precision': 0.9166666666666666, 'recall': 0.7333333333333333, 'specificity': np.float64(0.96), 'f1': 0.8148148148148148, 'micro-f1': 0.875, 'macro-f1': 0.8602375960866526, 'weighted-f1': 0.8715932914046121, 'mcc': 0.7324670207647144, 'kappa': 0.7222222222222222, 'g-mean': np.float64(0.8390470785361213), 'roc-auc': 0.9333333333333333, 'avg-roc-auc': 0.9333333333333333, 'pr-auc': 0.9184766607347252, 'brier-score': 0.1131475, 'log-loss': 0.37717526311691774}
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [METRICS] test: {'accuracy': 0.926829268292683, 'balanced-accuracy': 0.9571428571428571, 'precision': 0.6666666666666666, 'recall': 1.0, 'specificity': np.float64(0.9142857142857143), 'f1': 0.8, 'micro-f1': 0.926829268292683, 'macro-f1': 0.8776119402985074, 'weighted-f1': 0.9325081907535492, 'mcc': 0.7807200583588265, 'kappa': 0.757396449704142, 'g-mean': np.float64(0.9561828874675149), 'roc-auc': 0.9809523809523809, 'avg-roc-auc': 0.9809523809523809, 'pr-auc': 0.9107142857142857, 'brier-score': 0.08058292682926829, 'log-loss': 0.29910634094082167}
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/nc-antifungal/rf_test/ecfp_split/fold_3/run_45
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [RUN_MULTI] running seed=46, fold=4
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [RUN] rf_test | seed=46, fold=4, split=ecfp_split
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | Set official split ===ecfp_split=== with seed ====4=== successfully
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 0.12s
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/nc-antifungal/rf_test/ecfp_split/fold_4/run_46/model.joblib
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [METRICS] train: {'accuracy': 1.0, 'balanced-accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'specificity': np.float64(1.0), 'f1': 1.0, 'micro-f1': 1.0, 'macro-f1': 1.0, 'weighted-f1': 1.0, 'mcc': 1.0, 'kappa': 1.0, 'g-mean': np.float64(1.0), 'roc-auc': 1.0, 'avg-roc-auc': 1.0, 'pr-auc': 1.0, 'brier-score': 0.007978571428571427, 'log-loss': 0.06488531508341502}
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [METRICS] valid: {'accuracy': 0.9, 'balanced-accuracy': 0.8746081504702194, 'precision': 0.8181818181818182, 'recall': 0.8181818181818182, 'specificity': np.float64(0.9310344827586207), 'f1': 0.8181818181818182, 'micro-f1': 0.9, 'macro-f1': 0.8746081504702194, 'weighted-f1': 0.9, 'mcc': 0.7492163009404389, 'kappa': 0.7492163009404389, 'g-mean': np.float64(0.8727860481775684), 'roc-auc': 0.9404388714733543, 'avg-roc-auc': 0.9404388714733543, 'pr-auc': 0.8994949494949496, 'brier-score': 0.0919, 'log-loss': 0.3114283472356489}
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [METRICS] test: {'accuracy': 0.926829268292683, 'balanced-accuracy': 0.95, 'precision': 0.7857142857142857, 'recall': 1.0, 'specificity': np.float64(0.9), 'f1': 0.88, 'micro-f1': 0.926829268292683, 'macro-f1': 0.9136842105263158, 'weighted-f1': 0.9292939666238768, 'mcc': 0.8409178658720822, 'kappa': 0.8284518828451883, 'g-mean': np.float64(0.9486832980505138), 'roc-auc': 0.9893939393939394, 'avg-roc-auc': 0.9893939393939394, 'pr-auc': 0.964967860422406, 'brier-score': 0.08885609756097562, 'log-loss': 0.32414960786413044}
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/nc-antifungal/rf_test/ecfp_split/fold_4/run_46
# 2026-03-28 13:47:33 | INFO     | pepbenchmark | [RUN_MULTI DONE] total runs: 5
#    random_seed  fold_seed model_name  train_samples  valid_samples  \
# 0           42          0    rf_test            322             40
# 1           43          1    rf_test            322             40
# 2           44          2    rf_test            322             40
# 3           45          3    rf_test            322             40
# 4           46          4    rf_test            322             40
#
#    test_samples  training_time  train_accuracy  train_balanced-accuracy  \
# 0            41       0.119117             1.0                      1.0
# 1            41       0.116263             1.0                      1.0
# 2            41       0.117100             1.0                      1.0
# 3            41       0.116338             1.0                      1.0
# 4            41       0.117633             1.0                      1.0
#
#    train_precision  ...  test_macro-f1  test_weighted-f1  test_mcc  \
# 0              1.0  ...       0.774725          0.816939  0.593520
# 1              1.0  ...       0.711944          0.797624  0.458074
# 2              1.0  ...       0.806734          0.830878  0.614665
# 3              1.0  ...       0.877612          0.932508  0.780720
# 4              1.0  ...       0.913684          0.929294  0.840918
#
#    test_kappa  test_g-mean  test_roc-auc  test_avg-roc-auc  test_pr-auc  \
# 0    0.560322     0.834730      0.945161          0.945161     0.852157
# 1    0.434916     0.768706      0.920455          0.920455     0.801091
# 2    0.613728     0.811998      0.947802          0.947802     0.891516
# 3    0.757396     0.956183      0.980952          0.980952     0.910714
# 4    0.828452     0.948683      0.989394          0.989394     0.964968
#
#    test_brier-score  test_log-loss
# 0          0.114198       0.371462
# 1          0.135551       0.423238
# 2          0.110363       0.366119
# 3          0.080583       0.299106
# 4          0.088856       0.324150
#
# [5 rows x 58 columns]
# {'mean': 0.9567528707851288, 'std': 0.02820949910283763, 'min': 0.9204545454545454, 'max': 0.9893939393939394}

# %% [markdown]
# # 4. non-canonical peptide regression

# %%
from pepbenchmark.model.fp_model import build_fp_model
from pepbenchmark.dataset_manager.single_dataset import SinglePeptideDatasetManager

dataset = SinglePeptideDatasetManager(
    "nc-cpp_pampa",
    official_feature_names=["ecfp6", "label"],
    dataset_dir="../../PepBenchData/PepBenchData-50",
)
runner = build_fp_model(
    "rf",
    model_name="rf_test",
    dataset=dataset,
    task_type="regression",
    fingerprint_type="ecfp6",
)

multi_results = runner.run_multi(
    run_seeds=[42, 43, 44, 45, 46],
    fold_seeds=[0, 1, 2, 3, 4],
    split_type="ecfp_split",   
    base_dir="./results",
)
print(multi_results.to_dataframe())
summary = multi_results.get_summary_stats()
print(summary["test_mae"])
# Out:
# 2026-03-28 11:15:16 | INFO     | pepbenchmark | Loaded official feature: ecfp6
# 2026-03-28 11:15:16 | INFO     | pepbenchmark | Loaded official feature: label
# 2026-03-28 11:15:16 | INFO     | pepbenchmark | [RUN_MULTI] running seed=42, fold=0
# 2026-03-28 11:15:16 | INFO     | pepbenchmark | [RUN] rf_test | seed=42, fold=0, split=ecfp_split
# 2026-03-28 11:15:16 | INFO     | pepbenchmark | Set official split ===ecfp_split=== with seed ====0=== successfully
# 2026-03-28 11:15:16 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 11:15:30 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 13.73s
# 2026-03-28 11:15:30 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/nc-cpp_pampa/rf_test/ecfp_split/fold_0/run_42/model.joblib
# 2026-03-28 11:15:31 | INFO     | pepbenchmark | [METRICS] train: {'mse': 0.14843237513874638, 'rmse': np.float64(0.3852692242299486), 'mae': 0.279847951836046, 'r2': 0.7159112919831718, 'pcc': np.float64(0.8467606146066888), 'spearman': np.float64(0.8099875411376527)}
# 2026-03-28 11:15:31 | INFO     | pepbenchmark | [METRICS] valid: {'mse': 0.7465028758078935, 'rmse': np.float64(0.8640039790463314), 'mae': 0.6500783279176172, 'r2': 0.25193778057886884, 'pcc': np.float64(0.5092315722528287), 'spearman': np.float64(0.530454811123049)}
# 2026-03-28 11:15:31 | INFO     | pepbenchmark | [METRICS] test: {'mse': 0.7248495220713851, 'rmse': np.float64(0.8513809500284729), 'mae': 0.6448599159295926, 'r2': 0.15501581199731673, 'pcc': np.float64(0.41557821208881573), 'spearman': np.float64(0.4560197550293574)}
# 2026-03-28 11:15:31 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/nc-cpp_pampa/rf_test/ecfp_split/fold_0/run_42
# 2026-03-28 11:15:31 | INFO     | pepbenchmark | [RUN_MULTI] running seed=43, fold=1
# 2026-03-28 11:15:31 | INFO     | pepbenchmark | [RUN] rf_test | seed=43, fold=1, split=ecfp_split
# 2026-03-28 11:15:31 | INFO     | pepbenchmark | Set official split ===ecfp_split=== with seed ====1=== successfully
# 2026-03-28 11:15:31 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 11:15:45 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 14.21s
# 2026-03-28 11:15:45 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/nc-cpp_pampa/rf_test/ecfp_split/fold_1/run_43/model.joblib
# 2026-03-28 11:15:45 | INFO     | pepbenchmark | [METRICS] train: {'mse': 0.14830102146384944, 'rmse': np.float64(0.38509871651805), 'mae': 0.27988509224909663, 'r2': 0.7161606195228684, 'pcc': np.float64(0.8469231916539965), 'spearman': np.float64(0.8098312737375812)}
# 2026-03-28 11:15:45 | INFO     | pepbenchmark | [METRICS] valid: {'mse': 0.6972004949734822, 'rmse': np.float64(0.8349853262024921), 'mae': 0.6345792375993724, 'r2': 0.30568632042371047, 'pcc': np.float64(0.5535062984567689), 'spearman': np.float64(0.5690648536508859)}
# 2026-03-28 11:15:45 | INFO     | pepbenchmark | [METRICS] test: {'mse': 0.725711782558053, 'rmse': np.float64(0.8518871888683694), 'mae': 0.6561269241159603, 'r2': 0.1317734944692599, 'pcc': np.float64(0.3941282432892307), 'spearman': np.float64(0.43554290755175995)}
# 2026-03-28 11:15:45 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/nc-cpp_pampa/rf_test/ecfp_split/fold_1/run_43
# 2026-03-28 11:15:45 | INFO     | pepbenchmark | [RUN_MULTI] running seed=44, fold=2
# 2026-03-28 11:15:45 | INFO     | pepbenchmark | [RUN] rf_test | seed=44, fold=2, split=ecfp_split
# 2026-03-28 11:15:45 | INFO     | pepbenchmark | Set official split ===ecfp_split=== with seed ====2=== successfully
# 2026-03-28 11:15:45 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 11:15:58 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 13.08s
# 2026-03-28 11:15:58 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/nc-cpp_pampa/rf_test/ecfp_split/fold_2/run_44/model.joblib
# 2026-03-28 11:15:59 | INFO     | pepbenchmark | [METRICS] train: {'mse': 0.14860546236993247, 'rmse': np.float64(0.3854937903130639), 'mae': 0.2800527880455676, 'r2': 0.7153407834568493, 'pcc': np.float64(0.8463727917089297), 'spearman': np.float64(0.8094303425820623)}
# 2026-03-28 11:15:59 | INFO     | pepbenchmark | [METRICS] valid: {'mse': 0.7356824178739984, 'rmse': np.float64(0.8577193118229287), 'mae': 0.6539985153784399, 'r2': 0.27416579863938284, 'pcc': np.float64(0.5252181678219685), 'spearman': np.float64(0.53325036613702)}
# 2026-03-28 11:15:59 | INFO     | pepbenchmark | [METRICS] test: {'mse': 0.7130040473672861, 'rmse': np.float64(0.8443956699126814), 'mae': 0.6455204640024942, 'r2': 0.1447529907410533, 'pcc': np.float64(0.4032720743843311), 'spearman': np.float64(0.44500607101260986)}
# 2026-03-28 11:15:59 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/nc-cpp_pampa/rf_test/ecfp_split/fold_2/run_44
# 2026-03-28 11:15:59 | INFO     | pepbenchmark | [RUN_MULTI] running seed=45, fold=3
# 2026-03-28 11:15:59 | INFO     | pepbenchmark | [RUN] rf_test | seed=45, fold=3, split=ecfp_split
# 2026-03-28 11:15:59 | INFO     | pepbenchmark | Set official split ===ecfp_split=== with seed ====3=== successfully
# 2026-03-28 11:15:59 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 11:16:11 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 12.59s
# 2026-03-28 11:16:11 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/nc-cpp_pampa/rf_test/ecfp_split/fold_3/run_45/model.joblib
# 2026-03-28 11:16:12 | INFO     | pepbenchmark | [METRICS] train: {'mse': 0.14857418132063688, 'rmse': np.float64(0.38545321547580436), 'mae': 0.2799701109924565, 'r2': 0.7143637568585519, 'pcc': np.float64(0.8458196181070485), 'spearman': np.float64(0.8090425596066675)}
# 2026-03-28 11:16:12 | INFO     | pepbenchmark | [METRICS] valid: {'mse': 0.741309576676937, 'rmse': np.float64(0.8609933662212137), 'mae': 0.6458596333698772, 'r2': 0.27147248339160623, 'pcc': np.float64(0.5273526771885224), 'spearman': np.float64(0.540920021326948)}
# 2026-03-28 11:16:12 | INFO     | pepbenchmark | [METRICS] test: {'mse': 0.7221611083322308, 'rmse': np.float64(0.8498006285783923), 'mae': 0.6467450869809066, 'r2': 0.1594370034372543, 'pcc': np.float64(0.4215720842007184), 'spearman': np.float64(0.45697274232465546)}
# 2026-03-28 11:16:12 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/nc-cpp_pampa/rf_test/ecfp_split/fold_3/run_45
# 2026-03-28 11:16:12 | INFO     | pepbenchmark | [RUN_MULTI] running seed=46, fold=4
# 2026-03-28 11:16:12 | INFO     | pepbenchmark | [RUN] rf_test | seed=46, fold=4, split=ecfp_split
# 2026-03-28 11:16:12 | INFO     | pepbenchmark | Set official split ===ecfp_split=== with seed ====4=== successfully
# 2026-03-28 11:16:12 | INFO     | pepbenchmark | [BUILD MODEL] rf_test
# 2026-03-28 11:16:25 | INFO     | pepbenchmark | [TRAIN DONE] rf_test in 12.71s
# 2026-03-28 11:16:25 | INFO     | pepbenchmark | [SAVE MODEL] rf_test saved to ./results/nc-cpp_pampa/rf_test/ecfp_split/fold_4/run_46/model.joblib
# 2026-03-28 11:16:25 | INFO     | pepbenchmark | [METRICS] train: {'mse': 0.14825545716596203, 'rmse': np.float64(0.3850395527292774), 'mae': 0.2796189700188579, 'r2': 0.7149596955902832, 'pcc': np.float64(0.8462697090492095), 'spearman': np.float64(0.8094350425501516)}
# 2026-03-28 11:16:25 | INFO     | pepbenchmark | [METRICS] valid: {'mse': 0.7666493832166887, 'rmse': np.float64(0.8755851661698528), 'mae': 0.6543397118461143, 'r2': 0.2639018747491342, 'pcc': np.float64(0.5192338809891904), 'spearman': np.float64(0.5432204048221235)}
# 2026-03-28 11:16:25 | INFO     | pepbenchmark | [METRICS] test: {'mse': 0.7035360020156816, 'rmse': np.float64(0.8387705300114457), 'mae': 0.6352623701900907, 'r2': 0.1628796445619508, 'pcc': np.float64(0.42133029184972803), 'spearman': np.float64(0.4565995180985863)}
# 2026-03-28 11:16:25 | INFO     | pepbenchmark | [SAVE RESULTS] Saving results at ./results/nc-cpp_pampa/rf_test/ecfp_split/fold_4/run_46
# 2026-03-28 11:16:25 | INFO     | pepbenchmark | [RUN_MULTI DONE] total runs: 5
#    random_seed  fold_seed model_name  train_samples  valid_samples  \
# 0           42          0    rf_test           5576            697
# 1           43          1    rf_test           5576            697
# 2           44          2    rf_test           5576            697
# 3           45          3    rf_test           5576            697
# 4           46          4    rf_test           5576            697
#
#    test_samples  training_time  train_mse  train_rmse  train_mae  ...  \
# 0           697      13.725575   0.148432    0.385269   0.279848  ...
# 1           697      14.210291   0.148301    0.385099   0.279885  ...
# 2           697      13.082420   0.148605    0.385494   0.280053  ...
# 3           697      12.594654   0.148574    0.385453   0.279970  ...
# 4           697      12.712986   0.148255    0.385040   0.279619  ...
#
#    valid_mae  valid_r2  valid_pcc  valid_spearman  test_mse  test_rmse  \
# 0   0.650078  0.251938   0.509232        0.530455  0.724850   0.851381
# 1   0.634579  0.305686   0.553506        0.569065  0.725712   0.851887
# 2   0.653999  0.274166   0.525218        0.533250  0.713004   0.844396
# 3   0.645860  0.271472   0.527353        0.540920  0.722161   0.849801
# 4   0.654340  0.263902   0.519234        0.543220  0.703536   0.838771
#
#    test_mae   test_r2  test_pcc  test_spearman
# 0  0.644860  0.155016  0.415578       0.456020
# 1  0.656127  0.131773  0.394128       0.435543
# 2  0.645520  0.144753  0.403272       0.445006
# 3  0.646745  0.159437  0.421572       0.456973
# 4  0.635262  0.162880  0.421330       0.456600
#
# [5 rows x 25 columns]
# {'mean': 0.6457029522438089, 'std': 0.0074076818271203715, 'min': 0.6352623701900907, 'max': 0.6561269241159603}
